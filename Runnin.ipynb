# %%
PATH_TO_SCANNET = "\"/mnt/g/ScanNet/\""

! python tools/tsdf_fusion/generate_gt.py --data_path $PATH_TO_SCANNET --save_name all_tsdf_9 --window_size 9 --n_proc 1 --n_gpu 1 --num_workers 2 --loader_num_workers 2
# Out:
# ...
# 100%|██████████| 660/660 [00:00<00:00, 921.11it/s]

# %%
PATH_TO_SCANNET = "\"/mnt/g/ScanNet/\""

! python tools/tsdf_fusion/generate_gt.py --test --data_path $PATH_TO_SCANNET --save_name all_tsdf_9 --window_size 9 --n_proc 1 --n_gpu 1 --num_workers 1 --loader_num_workers 1
# Out:
# (process_with_single_worker pid=6897) read from disk
#   0%|          | 0/1 [00:00<?, ?it/s]pid=6897)
# (process_with_single_worker pid=6897) scene0707_00: read frame 0/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 100/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 200/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 300/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 400/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 500/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 600/784
# (process_with_single_worker pid=6897) scene0707_00: read frame 700/784
# (process_with_single_worker pid=6897) Initializing voxel volume...
# (process_with_single_worker pid=6897) scene0707_00: Fusing frame 0/784
# (process_with_single_worker pid=6897) scene0707_00: Fusing frame 100/784
# (process_with_single_worker pid=6897) scene0707_00: Fusing frame 200/784
# ...

# %%
! python main.py --cfg ./config/test.yaml
# Out:
# number of gpus: 1
# creating log file ./checkpoints_/20220201_205858_test.log
# Traceback (most recent call last):
#   File "main.py", line 117, in <module>
#     train_dataset = MVSDataset(cfg.TRAIN.PATH, "train", transforms, cfg.TRAIN.N_VIEWS, len(cfg.MODEL.THRESHOLDS) - 1)
#   File "/home/florin/licenta/NeuralRecon/datasets/scannet.py", line 19, in __init__
#     self.metas = self.build_list()
#   File "/home/florin/licenta/NeuralRecon/datasets/scannet.py", line 31, in build_list
#     with open(os.path.join(self.datapath, self.tsdf_file, 'fragments_{}.pkl'.format(self.mode)), 'rb') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/e/licenta/NeuralRecon/ScanNet/all_tsdf_9/fragments_train.pkl'

# %%
import torch
torch.cuda.empty_cache()
! ./train.sh
# Out:
# number of gpus: 1
# creating log file ./checkpoints_/20220202_095901_train.log
# 2022-02-02 09:59:06.975 | INFO     | __main__:train:171 - resuming ./checkpoints_/model_000000.ckpt
# 2022-02-02 09:59:07.534 | INFO     | __main__:train:187 - start at epoch 1
# 2022-02-02 09:59:07.536 | INFO     | __main__:train:188 - Number of model parameters: 6307694
# 2022-02-02 09:59:07.536 | INFO     | __main__:train:196 - Epoch 1:
# /home/florin/miniconda3/envs/neucon/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
# ...

# %%
import torch

torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1060 6GB'
